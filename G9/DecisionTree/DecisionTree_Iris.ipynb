# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import tree

# %%
data = datasets.load_iris()

# %%
X = data.data
Y = data.target
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
tclf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
tclf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tclf.score(X_test,Y_test)
# Out:
# 0.9

# %%
tclf.score(X_train,Y_train)
# Out:
# 1.0

# %%
tree.plot_tree(tclf)
# Out:
# [Text(0.375, 0.9, 'x[2] <= -0.615\nentropy = 1.581\nsamples = 120\nvalue = [42, 42, 36]'),
#  Text(0.25, 0.7, 'entropy = 0.0\nsamples = 42\nvalue = [42, 0, 0]'),
#  Text(0.5, 0.7, 'x[3] <= 0.745\nentropy = 0.996\nsamples = 78\nvalue = [0, 42, 36]'),
#  Text(0.25, 0.5, 'x[2] <= 1.022\nentropy = 0.162\nsamples = 42\nvalue = [0, 41, 1]'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 41\nvalue = [0, 41, 0]'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.5, 'x[2] <= 0.677\nentropy = 0.183\nsamples = 36\nvalue = [0, 1, 35]'),
#  Text(0.625, 0.3, 'x[1] <= -0.191\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.875, 0.3, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]')]
