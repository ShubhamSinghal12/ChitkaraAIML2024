# %% [markdown]
# - matplotlib.pyplot
# - plot - 1List, 2List
# - themes = plt.style.available, plt.style.use()
# - ylabel, xlabel, title, show
# - grid,xlim,ylim
# - plot --> String ro,b--,rs,g^ --> r-red, o-dots
# - label in plot, legend
# - linewidth
# - Same thing with keyword arguments. color, c, linestyle, marker
# - Combine multiple plots in one plot --> Arg Comma sep in a single plot in plt doc string
# - get multiple plots and set those plots using plt.setp function --> Use both keyword args and matplot style string value pairs
# - figure,subplot for multiple plots
# - scatter
# - bar --> width, multiple bars like plot,tick_label
# - pie --> value,labels,explode(Highlighting the subject-- tuple like values for every weight),autopct
# - Histogram --> hist,alpha
# - Normal Distribution --> randn(Gives standard ND), normal(mean,sigma,size)
# - np.round

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
x = np.arange(11)
y1 = 2*x+3
y2 = 4*x+5

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
plt.plot(x,y1,label='Potato',c = 'r',marker='^',linestyle='--',linewidth=5,markerfacecolor='blue', markersize=12)
plt.plot(x,y2,label='Onion')
plt.xlabel('Quantity',fontdict=font)
plt.ylabel('Price',fontdict=font)
plt.title('Vegetable Prices',fontdict=font)
plt.legend()
plt.grid()
plt.show()

# %%
lines = plt.plot(x,y1,x,y2)
plt.setp(lines[0],label='Potato',c = 'r',marker='^',linestyle='--',linewidth=5,markerfacecolor='blue', markersize=12)
plt.setp(lines[1],'color','r',label='Onion')

plt.legend()
plt.show()

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
plt.scatter(x,y1,label='Potato',marker='^')
plt.scatter(x,y2,label='Onion',marker='*')
plt.xlabel('Quantity',fontdict=font)
plt.ylabel('Price',fontdict=font)
plt.title('Vegetable Prices',fontdict=font)
plt.legend()
plt.grid()
plt.show()

# %%
plt.style.use('dark_background')
x = np.array([1,2,3])*1.5
y1 = np.array([10,20,30])
y2 = np.array([13,22,35])

plt.bar(x,y1,width = 0.5,label = 'Previous Year',
        tick_label=['Silver','Gold','Platinum'])
plt.bar(x+0.5,y2,width = 0.5,label = 'Current Year')
plt.ylabel('Price')
plt.title('Metal Prices')
plt.legend()
plt.show()

# %%
plt.style.use('seaborn-v0_8')

# %%
plt.pie([10,20,10,40,10],labels=['a','b','c','d','e']
        ,explode = (0,0,0,0.1,0),shadow = True,autopct='%1.1f%%')
plt.show()

# %%
val1 = np.random.randint(30,70,100)
val2 = np.random.randint(50,90,100)

# %%
plt.hist(val1,histtype = 'barstacked',orientation= 'horizontal',alpha=0.5,linewidth=0.2, edgecolor="black",label='Class A')
plt.hist(val2,histtype = 'barstacked',orientation= 'horizontal',alpha=0.5,linewidth=0.2, edgecolor="black",label = 'Class B')
# plt.xlim(0,100)
# plt.ylim(0,25)

plt.xlabel('Buckets')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.legend()
plt.show()

# %%
n1 = np.round(np.random.normal(50,20,1000))
n2 = np.round(np.random.normal(80,10,1000))

# %%
snd1 = np.random.randn(1000)
n1 = np.round(snd1*20+50)
n2 = np.round(snd1*10+80)

# %%
plt.hist(n1,label='ClassA',alpha = 0.5)
plt.hist(n2,label='ClassB',alpha = 0.5)

plt.xlim(0,100)
plt.xlabel('Buckets')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.legend()
plt.show()

# %%
x = np.linspace(0,5,100)
y1 = np.sin(2*np.pi*x)
y2 = np.cos(2*np.pi*x)
y3 = np.tan(2*np.pi*x)
y4 = np.sinc(2*np.pi*x)

plt.figure(figsize=(8,6))
ax1 = plt.subplot(221)
plt.title('Sin Graph')
plt.plot(x,y1)

ax2 = plt.subplot(222)
plt.plot(x,y2)
plt.title('Cosine Graph')

plt.subplot(223,sharex=ax1)
plt.plot(x,y3)
plt.title('Tan Graph')

plt.subplot(224,sharex=ax2)
plt.plot(x,y4)
plt.title('SinC Graph')

plt.suptitle('Trignometric Graphs') 
plt.show()

# %%
x = np.linspace(0,5,100)
y1 = np.sin(2*np.pi*x)
y2 = np.cos(2*np.pi*x)

plt.figure(figsize=(8,4))
ax1 = plt.subplot(211)
ax1.plot(x,y1)
ax1.set_title('Sin Graph')


ax2 = plt.subplot(212,sharex=ax1)
ax2.plot(x,y2)
ax2.set_title('Cosine Graph')

plt.suptitle('Trignometric Graphs') 
plt.show()

# %%
plt.subplot?
# Out:
# Signature: plt.subplot(*args, **kwargs) -> 'Axes'
# Docstring:
# Add an Axes to the current figure or retrieve an existing Axes.
#
# This is a wrapper of `.Figure.add_subplot` which provides additional
# behavior when working with the implicit API (see the notes section).
#
# Call signatures::
#
#    subplot(nrows, ncols, index, **kwargs)
#    subplot(pos, **kwargs)
#    subplot(**kwargs)
#    subplot(ax)
#
# Parameters
# ----------
# *args : int, (int, int, *index*), or `.SubplotSpec`, default: (1, 1, 1)
#     The position of the subplot described by one of
#
#     - Three integers (*nrows*, *ncols*, *index*). The subplot will take the
#       *index* position on a grid with *nrows* rows and *ncols* columns.
#       *index* starts at 1 in the upper left corner and increases to the
#       right. *index* can also be a two-tuple specifying the (*first*,
#       *last*) indices (1-based, and including *last*) of the subplot, e.g.,
# ...
