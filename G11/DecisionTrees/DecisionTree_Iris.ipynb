# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn import tree

# %%
data = datasets.load_iris()

# %%
X = data.data
Y = data.target
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
tclf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
tclf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tclf.score(X_test,Y_test)
# Out:
# 0.9

# %%
tree.plot_tree(tclf)
# Out:
# [Text(0.375, 0.9375, 'x[2] <= -0.691\nentropy = 1.583\nsamples = 120\nvalue = [43, 38, 39]'),
#  Text(0.25, 0.8125, 'entropy = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.5, 0.8125, 'x[2] <= 0.618\nentropy = 1.0\nsamples = 77\nvalue = [0.0, 38.0, 39.0]'),
#  Text(0.25, 0.6875, 'x[3] <= 0.641\nentropy = 0.183\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.125, 0.5625, 'entropy = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(0.375, 0.5625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.6875, 'x[3] <= 0.903\nentropy = 0.378\nsamples = 41\nvalue = [0, 3, 38]'),
#  Text(0.625, 0.5625, 'x[2] <= 0.931\nentropy = 0.722\nsamples = 15\nvalue = [0, 3, 12]'),
#  Text(0.5, 0.4375, 'x[1] <= -0.053\nentropy = 0.881\nsamples = 10\nvalue = [0, 3, 7]'),
#  Text(0.375, 0.3125, 'x[1] <= -0.784\nentropy = 0.544\nsamples = 8\nvalue = [0, 1, 7]'),
#  Text(0.25, 0.1875, 'x[2] <= 0.789\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.125, 0.0625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.375, 0.0625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5, 0.1875, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.625, 0.3125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.75, 0.4375, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.875, 0.5625, 'entropy = 0.0\nsamples = 26\nvalue = [0, 0, 26]')]
