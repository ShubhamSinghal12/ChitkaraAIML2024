# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import tree

# %%
data = datasets.load_iris()

# %%
X = data.data
Y = data.target
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
tclf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
tclf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tclf.score(X_test,Y_test)
# Out:
# 0.9666666666666667

# %%
tree.plot_tree(tclf)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[3] <= -0.478\nentropy = 1.582\nsamples = 120\nvalue = [43, 37, 40]'),
#  Text(0.3333333333333333, 0.75, 'entropy = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.5555555555555556, 0.75, 'x[3] <= 0.758\nentropy = 0.999\nsamples = 77\nvalue = [0.0, 37.0, 40.0]'),
#  Text(0.4444444444444444, 0.5833333333333334, 'x[2] <= 0.696\nentropy = 0.527\nsamples = 42\nvalue = [0, 37, 5]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'x[3] <= 0.628\nentropy = 0.183\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.1111111111111111, 0.25, 'entropy = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(0.3333333333333333, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[3] <= 0.498\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.5555555555555556, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.7777777777777778, 0.25, 'x[2] <= 0.974\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8888888888888888, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'entropy = 0.0\nsamples = 35\nvalue = [0, 0, 35]')]
