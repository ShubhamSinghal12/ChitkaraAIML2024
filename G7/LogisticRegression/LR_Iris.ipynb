# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
data = datasets.load_iris()
# data

# %%
X = data.data
Y = data.target

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
clf = LogisticRegression(max_iter=1000)

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
clf.coef_
# Out:
# array([[-1.02601533,  1.04666582, -1.77707433, -1.69228721],
#        [ 0.49860177, -0.42532431, -0.31973405, -0.65444437],
#        [ 0.52741356, -0.62134151,  2.09680839,  2.34673158]])

# %%
clf.intercept_
# Out:
# array([-0.00449383,  1.92472147, -1.92022763])

# %%
clf.score(X_test,Y_test)
# Out:
# 0.9666666666666667

# %%
ypred = clf.predict(X_test)

# %%
ypred
# Out:
# array([1, 2, 0, 1, 0, 1, 0, 1, 2, 1, 2, 1, 2, 1, 2, 0, 0, 0, 2, 2, 2, 1,
#        2, 2, 1, 0, 0, 2, 1, 2])

# %%
# clf.predict_proba(X_test)

# %%
cm = confusion_matrix(Y_test,ypred)

# %%
sns.heatmap(cm,annot = True,xticklabels=data.target_names,yticklabels=data.target_names)
plt.show()
